# %% [markdown]
# ### Slide03 Crash course of Python - Part 1
# Based on Learning Python (by Mark Lutz & David Ascher) and A Crash Course in Python (Cuauhtémoc Carbajal)

# %%
3234*444

# %% [markdown]
# # Outlines
# - Why Python
# - Python References
# - Python Advantages
# - Python Toolkit
# - Getting Python
# - Running Python
# - Python Principles
# - Python Language and Examples

# %% [markdown]
# # References
# - Primary Web Site: https://www.python.org
# - Learn Python online: https://www.learnpython.org/
# - Books
#     - Learning Python by Mark Lutz & David Ascher, O'Reilly, ISBN 1-56592-464-9
#     - The Quick Python Book by Daryl Harms and Kenneth McDonald, Manning, ISBN 1-884777-74-0
#     - Python and Tkinter Programming by John E. Grayson, Manning, ISBN 1-884777-81-3

# %% [markdown]
# # Why Python? It’s Easy to Use
#
# - High-level language: Distinct from the low-level processor operations; closer to human language than machine language
# - "Programming at the speed of thought"
# - Increases productivity
# - Python programs three to five times shorter than Java
# - Python programs five to ten times shorter than C++
# - Normally, “Programming is like making fine furniture with an axe and a nail file.”
# - Python makes it more like working with a table saw & a lathe
# - You still have to learn how to use them, but they’re the right tools for the job

# %% [markdown]
# # Python is Easy-to-Use
# ## Python Program

# %%
print("Game Over!")
print("Ryan")

# %%
print("Hello World!")

# %% [markdown]
# ## C++ Program

# %% [raw]
# #include <iostream>
# int main()
# {
#   std::cout << "Game Over!" << std::endl;
#   return 0;
# }

# %% [markdown]
# # Python is Powerful
# - Used by large organizations
#     - NASA
#     - Google
#     - Microsoft
# - Used in published games
#     - Battlefield 2
#     - Civilization IV
#     - Disney’s Toontown Online
# - Used throughout academia and the scientific community

# %% [markdown]
# # Python is Object-Oriented
# * Object-oriented programming (OOP):
#     * Methodology that defines problems in terms of objects that send messages to each other
#     * In a game, a Missile object could send a Ship object a message to Explode
# * OOP not required, unlike Java and C#
#
# <div>
# <img src="attachment:image.png" width="40%"/>
# </div>

# %% [markdown]
# # Python is a “Glue” Language
# - Can be integrated with other languages
#     - C/C++
#     - Java
# - Use existing code
# - Leverage strengths of other languages
#     - Extra speed that C or C++ offers

# %% [markdown]
# # Python runs Everywhere
# - Platform independent
#     - Independent of the specific computer operating system
# - Python runs on
#     - Windows
#     - DOS
#     - Mac OS X
#     - Linux
#     - Many more

# %% [markdown]
# # Python has a Strong Community
# - As an approachable language, has approachable community
# - Python Tutor mailing list
#     - http://mail.python.org/mailman/listinfo/tutor
# - Perfect for beginners
# - No actual "tutors" or "students"

# %% [markdown]
# # Python is Free and Open Source
# - Open source: Publicly available; open source software typically programmed by volunteers; anyone can use source code without fee
# - Can modify or even resell Python
# - Embracing open-source ideals is part of what makes Python successful

# %% [markdown]
# # Python is Popular
#
# ![image-2.png](attachment:image-2.png)
#
# * All those advantages make Python a commonly used (and liked) language
#     * https://www.tiobe.com/tiobe-index/

# %% [markdown]
# # Fastest Way to Learn
# * Study examples
# * Lay foundations without surprises
# * Note the exceptions to experience
# * Do quick pop quizzes
# * Practice what you have learned

# %% [markdown]
# # Python Advantages
# * Object-Oriented
# * Dynamic Type Checking makes it inherently generic – C++ templates for free!
# * Free, as in Open Source free
# * <font color='red'>Portable</font>
# * <font color='red'>Powerful language constructs / features</font>
# * <font color='red'>Powerful toolkit / library</font>
# * Mixable with other languages
# * Easy to use & learn

# %% [markdown]
# # Python Toolkit
# * <font color='red'>Dynamic typing</font>
# * Built-in object types
# * Built-in tools
# * <font color='red'>Library utilities</font>
# * <font color='red'>Third-party utilities</font>
# * <font color='red'>Automatic memory management</font>
# * Programming-in-the-large support

# %% [markdown]
# # How Python Is Used
# * System utilities
# * GUIs using Tkinter
# * Component integration
# * Rapid prototyping
# * Internet scripting
# * Database programming

# %% [markdown]
# # Getting Python
#
# * Official web site
#     * www.python.org
# * Anaconda - The World's Most Popular Data Science Platform
#     * https://www.anaconda.com
#
# * IDE - Eclipse
#     * https://www.eclipse.org
# * IDE - Visual Studio Code
#     * https://code.visualstudio.com
# * IDE - Sublime (not free)

# %% [markdown]
# # Running Python (1)

# %%
print(9) # Integer
print(2*9/2) # Float
print("my first program done, hehehaha")

# %% [markdown]
# * Suppose you save the code in a file "mypgm.py"
# * As Python module files:
#     * [WIN] C:\user\addoil> python mypgm.py
#     * [LINUX] /home/addoil/python mypgm.py

# %% [markdown]
# # Running Python (2)
# * from platform specific shell
#     * #!/usr/local/bin/python
#     * print("Hello there")
#
# * or
#     * #!/usr/bin/env python
#     * print("Hello there")

# %% [markdown]
# # Running Python (3)
# * Embedded in another system

# %% [raw]
# #include <Python.h>
# int main(int argc, char *argv[])
# {
#   Py_SetProgramName(argv[0]);  /* optional but recommended */
#   Py_Initialize();
#   PyRun_SimpleString("from time import time,ctime\n"
#                      "print 'Today is',ctime(time())\n");
#   Py_Finalize();
#   return 0;
# }

# %% [markdown]
# # Simple examples

# %%
print("hello world!")

# %%
print("A b")
ALongName = 210/3

# %%
BLongName = 260/5
print(ALongName+BLongName)

# %% [markdown]
# # Python Principles
# * Python treats everything as an object
# * Python is an interpreter
#     * It gives immediate results
#     * It generates byte code (similar to Java)

# %% [markdown]
# # Built-in Object Types
# <div>
# <img src="attachment:image.png" width="50%"/>
# </div>

# %%
a=5.2; b="Ryan"; c=[1,[2,2.1],3,4]
print(type(a));
print(type(b));
print(c[1][1]);

# %% [markdown]
# # Operator Precedence
# <div>
# <img src="attachment:image.png" width="50%"/>
# </div>

# %%
x=1; y=2; z=3
print(x+y*z);
print(x&y*z); 
print(x < x& y*z)

# %% [markdown]
# # Basic Operations (1)

# %%
# Assignment creates names
s = "A string" # variable s is created
print(s)

# %%
# Variable name can be any length and is case sensitive
# Semicolons separate statements on the same line 
A = 1; a = 2; print(A+a)

# %% [markdown]
# # Basic Operations (2)

# %%
print(1.0/2.0)
print(1/2.0)
print(1/2)

# %% [markdown]
# * Things changed in Python 3
#     * https://sebastianraschka.com/Articles/2014_python_2_3_key_diff.html#python-2

# %% [markdown]
# # Basic Operations (3)

# %%
# Boolean True is non-zero, non-NULL, non-empty
print("a"=='a')
print((1,2)==(1,2))
verify = (1,3)==(1,2)
print(verify)
print([3])

# %%
# Boolean False = not True
print("a"!='a'); print((2)!=(2)); print(not [3])

# %% [markdown]
# # Basic Numeric Operations

# %%
x = 1
print(x << 2) # bit shift 2 bits
print(x|2)    # bitwise OR

# %%
print(9999999999999999999999999999999999999999999999+1)

# %%
print(2 + -5j, 1j * 1j)
print(2 + 3j * 2)
print((2+3j) * 3)

# %% [markdown]
# # Exercise 1
# 1. Write a script that request two number from user
# 2. Make a sum with the two numbers and save result in a variable.
# 3. Finally print result variable

# %%
## Request first number from user.
a = float(input("first number: "))
# Request second number to user. 
b = float(input("second number: "))
c = a+b
print(c)

# %% [markdown]
# # Exercise 2
# Create an algorithm to calculate perimeter and area of a circle
#
# 1. Create a variable with  pi value
# 2. Request radius to the user
# 3. Calculate perimeter and save in variable
# 4. Calculate area and save in variable
# 5. Print in screen perimeter and area variables

# %%
PI = 3.141592 # https://www.w3schools.com/python/ref_math_pi.asp
import math
r = float(input("radius: "))
p = 2 * math.pi * r
a = math.pi * r ** 2
print(p)
print(a)

# %% [markdown]
# # Strings
# * Sequence of immutable characters (characters can't be changed in-place).
# * https://www.tutorialspoint.com/python/python_strings.htm

# %%
a="I'm an oragne."
print(a)

# %%
print("""Spans two 
lines""")

# %%
print('a'*3+'bb')

# %%
print(('a'+'b')*7)

# %% [markdown]
# # String Operations

# %%
s='abcdefg'
print(s[-2]) # index (zero based)

# %%
print(s[1:]) # slice to end

# %%
print(s[2:-2]) # slice from start

# %%
print(s[0:3]) # slice in middle
print(s[1:2])

# %%
print(len(s)) # length

# %% [markdown]
# # String Operations (continue)

# %%
for i in s:   # iteration
    print(i)

# %%
print('z' in s) # membership

# %% [markdown]
# # String Formatting
# * Like C's printf with similar specifiers

# %%
"It's {} great life!".format("10")

# %%
"{} {} much".format("Python's",3)

# %% [markdown]
# # Lists

# %%
# Sequence of mutable heterogeneous objects (items can be changed in-place).
L = [1, "a", [3, {"d":4}, 4, [5,6]]]
#print([1, "a", [3, {"d":4}, 4]])
print(L)

# %%
print([1, 2, 3][1:2]) #slicing from position #1 before position #2

# %%
print([1] + list('ab' + '76')) # character list
print([1]+['ab','76'])

# %%
L = [1, 2, 3]; L[2]=6; print(L); # update

# %%
L = [1, 2, 3]; del L[1]; print(L); # deletion

# %%
L.append(7); print(L)

# %% [markdown]
# # Lists (2)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lists (3)
# * <font color='red'><b>List methods</b></font> work on the list object **itself**, not copies
# * Built-in operations work on copies

# %%
L = [1, 3]; L.append('a'); print(L)

# %%
L = [1, 3]; M = L+['a']; print(M)

# %%
print(L)

# %% [markdown]
# # Lists (4)
# * Shared references

# %%
X = [1, 2, 3]
L = ['a', X, 'c']
print(L)
# Out:
# ['a', [1, 2, 3], 'c']

# %%
X[1] = -9
print(X)
print(L)
# Out:
# [1, -9, 3]
# ['a', [1, 2, 3], 'c']

# %%
M = X[:] # make copy of X
X[0] = 'c'
print(X)
print(M)
# Out:
# ['c', -9, 3]
# [1, -9, 3]

# %% [markdown]
# # List Comprehensions
# * List comprehensions provide a concise way to create lists.
# * https://www.geeksforgeeks.org/python-list-comprehension-and-slicing/

# %%
squares = [x**2 for x in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = [x**2 for x in range(10) if x**2>50]
print(squares)
# Out:
# [64, 81]

# %% [markdown]
# # Dictionaries
# * Mapping of unordered immutable keys to mutable heterogeneous objects

# %%
D={'a':1,'bbbb':[2,3], 1233:'c', 'ddd':'d'}
print(D[1233])
# Out:
# c

# %%
print(D[1233])

# %%
print(D.keys(), "|", len(D))
# Out:
# dict_keys(['a', 'bbbb', 1233, 'ddd']) | 4

# %%
print('1233' in D) # check existance in keys
# Out:
# False

# %%
D[1233]=list('xy'); print(D) # add a new key-value pair into Dict
# Out:
# {'a': 1, 'bbbb': [2, 3], 1233: ['x', 'y'], 'ddd': 'd'}

# %%
print(D.values())
# Out:
# dict_values([1, [2, 3], ['x', 'y'], 'd'])

# %%
del D['ryan']; print(D)
# Out:
# {'a': 1, 1233: ['x', 'y'], 'ddd': 'd'}

# %% [markdown]
# # Tuples
# * Sequence of ordered immutable heterogeneous objects.
# * Can not change number of elements in tuple.
#     * https://www.programiz.com/python-programming/list-vs-tuples

# %%
t = ('a',{'b': 2}); print(t)
# Out:
# ('a', {'b': 2})

# %%
print(t[1]['b'], len(t)+1)
# Out:
# 2 3

# %%
tuple(t[0]) + t
# Out:
# ('a', 'a', {'b': 2})

# %%
u = ('c',); u
# Out:
# ('c',)

# %%
for i in t: print(i)
# Out:
# a
# {'b': 2}

# %%
for i in t: print(i, end=", ")
# Out:
# a, {'b': 2},

# %%
import json
json.dumps(t)
# Out:
# '["a", {"b": 2}]'

# %% [markdown]
# # Comparisons, Equality
# * In comparisons, Python automatically traverses data structures checking all objects
# * Equivalence (==) tests value equality
# * Identity (is) compares <font color="red"><b>objects addresses</b></font>
#
# https://towardsdatascience.com/comparison-in-python-is-not-as-simple-as-you-may-think-a83eec69ab54

# %%
a='mary'
b='john'
print(a<b)
# Out:
# False

# %%
print(a==b)

# %%
a=1; print(a==b)
# Out:
# False

# %%
b=1; a=2; print(a is b)
# Out:
# False
# 1818901178704 1818901178672

# %% [markdown]
# # Files

# %%
Out = open('myF','w')  # Create output file myF
L = ['line 2\n', 'line ryan\n']
Out.write("line 1\n")
Out.writelines(L)
Out.close()

# %%
In = open('myF', 'r') # Open existing file myF

# %%
In.readlines() # reads line 2 and line 3
# Out:
# ['line 1\n', 'line 2\n', 'line ryan\n']

# %%
In.close()

# %%
a=2
a=a+2
while (1):
    a=a+2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [82], in <cell line: 4>()
#       2 a=a+2
#       3 while (1):
# ----> 4     a=a+2
#
# KeyboardInterrupt:

# %% [markdown]
# # Reserved Words
# <div>
# <img src="attachment:image.png" width="80%"/>
# </div>

# %% [markdown]
# # Statements
# * Defines variables names referring to objects
# * Forms RHS tuples and assigns pair-wise to LHS
# * Implicit assignments: import, from, def, class, for, function, argument, etc.

# %%
# Statements normally go to the end of line
a = "xxx" # assigning "xxx" to variable a

# %%
# Statements can be continued across lines if:
# There is an open syntactic unit: (), [], {}
a = [1, # comment1
     2] # comment2

# %%
# The statement line ends in a backslash
b = 'a' \
    'b'
print(b)
# Out:
# ab

# %%
# The statement contains part of a triple quote (literal includes new line char (\n))
c = """This is my letter to show my love to you

...
.≥..


best,
Paklon"""

print(c)
# Out:
# This is my letter to show my love to you
#
# ...
# .≥..
#
#
# best,
# Paklon

# %%
# Multiple statements separated by semicolons (;) on same line
d = "abc"; print(d)
# Out:
# abc

# %% [markdown]
# # Assignment Statement
# * Defines variables names referring to objects
# * Forms RHS tuples and assigns pair-wise to LHS
# * Implicit assignments: import, from, def, class, for, function, argument, etc.

# %%
a = "Normal assign"
print(a)
# Out:
# Normal assign

# %%
[a, b] = [1, 2]; print(a,b)
# Out:
# 1 2

# %%
[a,b]=[b,a]
print(a,b)
# Out:
# 2 1

# %%
a = b = "men"; b = "mice"
print(id(a), id(b))
# Out:
# 1816872299248 1816872298480

# %%
for c in "abc": 
    print(c,end=" ")
# Out:
# a b c
